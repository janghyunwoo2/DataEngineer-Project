# %%
# airflow 스케줄러 실행
# 쥬피터에서 실행말고 putty로 실행해라
# !airflow scheduler
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 05:01:48,040] {__init__.py:51} INFO - Using executor SequentialExecutor
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# [2022-07-13 05:01:48,267] {jobs.py:1500} INFO - Starting the scheduler
# [2022-07-13 05:01:48,267] {jobs.py:1508} INFO - Running execute loop for -1 seconds
# ...

# %%
# airflow 웹서버 실행
# 쥬피터에서 실행말고 putty로 실행해라
# !airflow webserver -p 8080
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 05:03:34,275] {__init__.py:51} INFO - Using executor SequentialExecutor
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# [2022-07-13 05:03:34,583] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# ...

# %%
# connections 생성
# 한번만 하면 되는듯?
# !airflow connections -a --conn_id emr_cluster_conn --conn_type SSH --conn_port 22
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 05:08:10,472] {__init__.py:51} INFO - Using executor SequentialExecutor
#
# 	A connection with `conn_id`=emr_cluster_conn already exists

# %%
# airflow DB 초기화
# !airflow initdb
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-14 00:30:12,669] {__init__.py:51} INFO - Using executor SequentialExecutor
# DB: sqlite:////home/ubuntu/project1/airflow/airflow.db
# [2022-07-14 00:30:13,138] {db.py:350} INFO - Creating tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# ...

# %%
# airflow dags에 DAG파일 넣기
# in 첫번째 매개변수는 DAG 파일 위치, 두번째 매개변수 airflow DAG 실행시킬 위치
# !ln -s ~/Project/02_Data_Batch_Processing/01_Data_Refine/data_refine_DAG.py ~/project1/airflow/dags

# %%
# 전체 테스트 220714에 성공 확인
# !airflow backfill -s 2019-08-01 -e 2019-08-01 DAG_data_refine
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-14 00:31:16,645] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-14 00:31:16,881] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# 전체 테스트 기록 지우기
# 쥬피터에서 실행말고 putty로 실행해라
# !airflow clear -s 2019-08-01 -e 2019-08-01 DAG_data_refine
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 05:13:18,329] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 05:13:18,533] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# 작업 단위로 테스트 하기 
# DAG_data_refine는 DAG id 뒤에오는 emr_cluster_create~emr_cluster_close까지 작업 id e
# !airflow test DAG_data_refine emr_cluster_create 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:01:58,126] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:01:58,326] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine emr_ssh_connect 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:09:42,011] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:09:42,214] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine ip_forwarding 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:09:47,388] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:09:47,590] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine rawdata_s3_to_hdfs 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:09:51,979] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:09:52,183] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine data_refine 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 11:07:34,490] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 11:07:34,784] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine refined_data_hdfs_to_s3 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:50:04,786] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:50:04,988] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine start_crawler 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 10:58:01,392] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 10:58:01,599] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...

# %%
# !airflow test DAG_data_refine emr_cluster_close 2019-08-01
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/configuration.py:590: DeprecationWarning: You have two airflow.cfg files: /home/ubuntu/airflow/airflow.cfg and /home/ubuntu/project1/airflow/airflow.cfg. Airflow used to look at ~/airflow/airflow.cfg, even when AIRFLOW_HOME was set to a different value. Airflow will now only read /home/ubuntu/project1/airflow/airflow.cfg, and you should remove the other file
#   category=DeprecationWarning,
# [2022-07-13 11:15:32,566] {__init__.py:51} INFO - Using executor SequentialExecutor
# [2022-07-13 11:15:32,773] {__init__.py:305} INFO - Filling up the DagBag from /home/ubuntu/project1/airflow/dags
# /home/ubuntu/.local/lib/python3.6/site-packages/airflow/utils/helpers.py:387: DeprecationWarning: Importing 'SSHHook' directly from 'airflow.contrib.hooks' has been deprecated. Please import from 'airflow.contrib.hooks.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)
# ...
